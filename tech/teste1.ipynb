# %%
import pandas as pd

# %%
dados = pd.read_excel('C:/Users/thelsandro/Documents/tech/_Desafio_2_relatorio.xlsx', sheet_name = "Dados - Questão 1")

# %%
dados.head(100)
# Out:
#     num_compra  usuario      nome    Tipo de Mercadoria           Filial  \
# 0     24937847      295  ANDERSON    SPLIT 8501 À 10000     Loja Autazes
# 1     23600787      331  RAIMUNDO  SPLIT INV 8501À10000  Loja Manicor é
# 2     24298956      370  ROSILANE  SPLIT ACIMA DE 30000  Loja Manicor é
# 3     23802765      460    SANDRA   SPLIT 10001 À 18000  Loja Manicor é
# 4     22559356      538  JAMERSON   SPLIT 18001 À 30000  Loja Manicor é
# ..         ...      ...       ...                   ...              ...
# 95    24765932    28069    DANIEL              MERGULHO  Loja Manicor é
# 96    24313851    28107     ILCIA   REL MASC AUTOMÁTICO     Loja Lábrea
# 97    24311018    28181       ANA   RELÓGIO MASC ANALÓG     Loja Lábrea
# 98    22476029    28211   JULIANA    RELÓGIO FEM ANALÓG     Loja Lábrea
# 99    24660686    28300   GABRIEL  RELÓGIO PULSO INF-JU     Loja Lábrea
#
#                data_compra  valor_compra    Imposto CPF NA NOTA?
# ...
